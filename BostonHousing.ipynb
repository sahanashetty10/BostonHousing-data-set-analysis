# %%
# Step1: use pandas to import the BostonHouse.xlsx dataset
import pandas as pd
# load excel dataset as a Pandas dataframe
house=pd.read_excel("BostonHousing.xlsx")

# Step2: See top few rows of dataset to check
house.head(10)
# Out:
#       crim    zn  indus  chas    nox     rm    age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2
# 5  394.12   5.21  28.7
# 6  395.60  12.43  22.9
# 7  396.90  19.15  27.1
# 8  386.63  29.93  16.5
# 9  386.71  17.10  18.9

# %%
# Step3: Explore the dataframe statistics. Get descriptive statistics
house.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             lstat        medv
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
# Step 4: Continue exploring by visualizing correlations between variables using matplotlib
import matplotlib.pyplot as plt

# %%
# Draw correlation values with color coding
# Dark colour shows highly correlated values.Blue is positive correlation.
# Light colour shows values that have less correlation. Brown shows negative correlation
correlation = house.corr ()
correlation.style.background_gradient (cmap = 'BrBG')
# Out:
# <style type="text/css">
# #T_22dc0_row0_col0, #T_22dc0_row1_col1, #T_22dc0_row2_col2, #T_22dc0_row3_col3, #T_22dc0_row4_col4, #T_22dc0_row5_col5, #T_22dc0_row6_col6, #T_22dc0_row7_col7, #T_22dc0_row8_col8, #T_22dc0_row9_col9, #T_22dc0_row10_col10, #T_22dc0_row11_col11, #T_22dc0_row12_col12, #T_22dc0_row13_col13 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_22dc0_row0_col1 {
#   background-color: #ca9849;
#   color: #f1f1f1;
# }
# #T_22dc0_row0_col2 {
#   background-color: #a0dad1;
#   color: #000000;
# }
# #T_22dc0_row0_col3 {
#   background-color: #734208;
#   color: #f1f1f1;
# }
# #T_22dc0_row0_col4 {
#   background-color: #92d4ca;
#   color: #000000;
# }
# #T_22dc0_row0_col5 {
#   background-color: #cd9d50;
#   color: #f1f1f1;
# }
# #T_22dc0_row0_col6, #T_22dc0_row1_col13 {
#   background-color: #b1e1da;
#   color: #000000;
# }
# #T_22dc0_row0_col7, #T_22dc0_row11_col4, #T_22dc0_row11_col10 {
#   background-color: #c58e3d;
#   color: #f1f1f1;
# }
# #T_22dc0_row0_col8 {
#   background-color: #5bb3a8;
#   color: #f1f1f1;
# }
# #T_22dc0_row0_col9, #T_22dc0_row2_col8, #T_22dc0_row8_col0 {
#   background-color: #6abdb2;
#   color: #000000;
# }
# #T_22dc0_row0_col10 {
#   background-color: #e7f2f0;
#   color: #000000;
# }
# #T_22dc0_row0_col11, #T_22dc0_row13_col9 {
#   background-color: #6a3d07;
#   color: #f1f1f1;
# }
# #T_22dc0_row0_col12 {
#   background-color: #8ad1c6;
#   color: #000000;
# }
# #T_22dc0_row0_col13, #T_22dc0_row9_col5 {
#   background-color: #bf812d;
#   color: #f1f1f1;
# }
# #T_22dc0_row1_col0 {
#   background-color: #9d6116;
#   color: #f1f1f1;
# }
# #T_22dc0_row1_col2, #T_22dc0_row1_col6, #T_22dc0_row8_col3 {
#   background-color: #8d520b;
#   color: #f1f1f1;
# }
# #T_22dc0_row1_col3 {
#   background-color: #794608;
#   color: #f1f1f1;
# }
# #T_22dc0_row1_col4, #T_22dc0_row1_col9 {
#   background-color: #a16518;
#   color: #f1f1f1;
# }
# #T_22dc0_row1_col5, #T_22dc0_row2_col0 {
#   background-color: #d4ede9;
#   color: #000000;
# }
# #T_22dc0_row1_col7, #T_22dc0_row9_col4, #T_22dc0_row13_col5 {
#   background-color: #2f9189;
#   color: #f1f1f1;
# }
# #T_22dc0_row1_col8, #T_22dc0_row5_col0 {
#   background-color: #975b12;
#   color: #f1f1f1;
# }
# #T_22dc0_row1_col10, #T_22dc0_row9_col3, #T_22dc0_row13_col8 {
#   background-color: #7e4909;
#   color: #f1f1f1;
# }
# #T_22dc0_row1_col11 {
#   background-color: #f6ecd1;
#   color: #000000;
# }
# #T_22dc0_row1_col12, #T_22dc0_row5_col2, #T_22dc0_row6_col3, #T_22dc0_row10_col11 {
#   background-color: #b77928;
#   color: #f1f1f1;
# }
# #T_22dc0_row2_col1, #T_22dc0_row7_col3 {
#   background-color: #5f3606;
#   color: #f1f1f1;
# }
# #T_22dc0_row2_col3, #T_22dc0_row8_col1 {
#   background-color: #ad7021;
#   color: #f1f1f1;
# }
# #T_22dc0_row2_col4 {
#   background-color: #12766e;
#   color: #f1f1f1;
# }
# #T_22dc0_row2_col5, #T_22dc0_row7_col12 {
#   background-color: #9f6317;
#   color: #f1f1f1;
# }
# #T_22dc0_row2_col6 {
#   background-color: #389991;
#   color: #f1f1f1;
# }
# #T_22dc0_row2_col7, #T_22dc0_row4_col1, #T_22dc0_row11_col8 {
#   background-color: #663a07;
#   color: #f1f1f1;
# }
# #T_22dc0_row2_col9 {
#   background-color: #2b8d85;
#   color: #f1f1f1;
# }
# #T_22dc0_row2_col10, #T_22dc0_row13_col1 {
#   background-color: #cbebe6;
#   color: #000000;
# }
# #T_22dc0_row2_col11, #T_22dc0_row11_col9, #T_22dc0_row12_col3 {
#   background-color: #754308;
#   color: #f1f1f1;
# }
# #T_22dc0_row2_col12, #T_22dc0_row6_col12, #T_22dc0_row12_col6 {
#   background-color: #4aa69d;
#   color: #f1f1f1;
# }
# #T_22dc0_row2_col13 {
#   background-color: #a3671a;
#   color: #f1f1f1;
# }
# #T_22dc0_row3_col0 {
#   background-color: #cc9a4c;
#   color: #f1f1f1;
# }
# #T_22dc0_row3_col1 {
#   background-color: #e7cf94;
#   color: #000000;
# }
# #T_22dc0_row3_col2 {
#   background-color: #f5efdc;
#   color: #000000;
# }
# #T_22dc0_row3_col4 {
#   background-color: #f5f3ee;
#   color: #000000;
# }
# #T_22dc0_row3_col5 {
#   background-color: #f6edd5;
#   color: #000000;
# }
# #T_22dc0_row3_col6 {
#   background-color: #f5f2ea;
#   color: #000000;
# }
# #T_22dc0_row3_col7 {
#   background-color: #f1dfb3;
#   color: #000000;
# }
# #T_22dc0_row3_col8, #T_22dc0_row3_col9 {
#   background-color: #e5cc8f;
#   color: #000000;
# }
# #T_22dc0_row3_col10 {
#   background-color: #d1a559;
#   color: #000000;
# }
# #T_22dc0_row3_col11 {
#   background-color: #e8d29a;
#   color: #000000;
# }
# #T_22dc0_row3_col12 {
#   background-color: #f4e5be;
#   color: #000000;
# }
# #T_22dc0_row3_col13 {
#   background-color: #e9f2f1;
#   color: #000000;
# }
# #T_22dc0_row4_col0, #T_22dc0_row12_col10 {
#   background-color: #ceece8;
#   color: #000000;
# }
# #T_22dc0_row4_col2 {
#   background-color: #147870;
#   color: #f1f1f1;
# }
# #T_22dc0_row4_col3, #T_22dc0_row5_col3, #T_22dc0_row5_col8 {
#   background-color: #b97b29;
#   color: #f1f1f1;
# }
# #T_22dc0_row4_col5, #T_22dc0_row13_col4 {
#   background-color: #bb7d2a;
#   color: #f1f1f1;
# }
# #T_22dc0_row4_col6 {
#   background-color: #1d8078;
#   color: #f1f1f1;
# }
# #T_22dc0_row4_col7, #T_22dc0_row6_col1, #T_22dc0_row7_col2, #T_22dc0_row7_col4, #T_22dc0_row7_col6, #T_22dc0_row7_col8, #T_22dc0_row7_col9, #T_22dc0_row8_col11, #T_22dc0_row9_col11, #T_22dc0_row10_col3, #T_22dc0_row11_col0, #T_22dc0_row12_col5, #T_22dc0_row12_col13, #T_22dc0_row13_col0, #T_22dc0_row13_col10, #T_22dc0_row13_col12 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# #T_22dc0_row4_col8 {
#   background-color: #61b7ac;
#   color: #f1f1f1;
# }
# #T_22dc0_row4_col9 {
#   background-color: #419f97;
#   color: #f1f1f1;
# }
# #T_22dc0_row4_col10 {
#   background-color: #f5f0e2;
#   color: #000000;
# }
# #T_22dc0_row4_col11 {
#   background-color: #6c3e07;
#   color: #f1f1f1;
# }
# #T_22dc0_row4_col12, #T_22dc0_row8_col2 {
#   background-color: #4faaa1;
#   color: #f1f1f1;
# }
# #T_22dc0_row4_col13 {
#   background-color: #b37625;
#   color: #f1f1f1;
# }
# #T_22dc0_row5_col1 {
#   background-color: #d9eeeb;
#   color: #000000;
# }
# #T_22dc0_row5_col4, #T_22dc0_row13_col3 {
#   background-color: #d3aa5f;
#   color: #000000;
# }
# #T_22dc0_row5_col6 {
#   background-color: #dcbc75;
#   color: #000000;
# }
# #T_22dc0_row5_col7 {
#   background-color: #ddefed;
#   color: #000000;
# }
# #T_22dc0_row5_col9, #T_22dc0_row10_col5 {
#   background-color: #a96c1e;
#   color: #f1f1f1;
# }
# #T_22dc0_row5_col10, #T_22dc0_row12_col1 {
#   background-color: #8b500a;
#   color: #f1f1f1;
# }
# #T_22dc0_row5_col11 {
#   background-color: #f5e7c0;
#   color: #000000;
# }
# #T_22dc0_row5_col12 {
#   background-color: #7c4709;
#   color: #f1f1f1;
# }
# #T_22dc0_row5_col13 {
#   background-color: #278a82;
#   color: #f1f1f1;
# }
# #T_22dc0_row6_col0 {
#   background-color: #e6f1f0;
#   color: #000000;
# }
# #T_22dc0_row6_col2 {
#   background-color: #3b9b93;
#   color: #f1f1f1;
# }
# #T_22dc0_row6_col4 {
#   background-color: #1a7e76;
#   color: #f1f1f1;
# }
# #T_22dc0_row6_col5 {
#   background-color: #c99546;
#   color: #f1f1f1;
# }
# #T_22dc0_row6_col7 {
#   background-color: #5b3406;
#   color: #f1f1f1;
# }
# #T_22dc0_row6_col8 {
#   background-color: #aee0d8;
#   color: #000000;
# }
# #T_22dc0_row6_col9 {
#   background-color: #8fd3c9;
#   color: #000000;
# }
# #T_22dc0_row6_col10, #T_22dc0_row7_col11 {
#   background-color: #f0f4f3;
#   color: #000000;
# }
# #T_22dc0_row6_col11 {
#   background-color: #955910;
#   color: #f1f1f1;
# }
# #T_22dc0_row6_col13 {
#   background-color: #c28633;
#   color: #f1f1f1;
# }
# #T_22dc0_row7_col0 {
#   background-color: #563105;
#   color: #f1f1f1;
# }
# #T_22dc0_row7_col1 {
#   background-color: #3e9d95;
#   color: #f1f1f1;
# }
# #T_22dc0_row7_col5 {
#   background-color: #f2f4f4;
#   color: #000000;
# }
# #T_22dc0_row7_col10 {
#   background-color: #b57826;
#   color: #f1f1f1;
# }
# #T_22dc0_row7_col13 {
#   background-color: #d5edea;
#   color: #000000;
# }
# #T_22dc0_row8_col4 {
#   background-color: #44a299;
#   color: #f1f1f1;
# }
# #T_22dc0_row8_col5 {
#   background-color: #cfa256;
#   color: #f1f1f1;
# }
# #T_22dc0_row8_col6 {
#   background-color: #87d0c5;
#   color: #000000;
# }
# #T_22dc0_row8_col7, #T_22dc0_row9_col13, #T_22dc0_row12_col7 {
#   background-color: #a76a1d;
#   color: #f1f1f1;
# }
# #T_22dc0_row8_col9 {
#   background-color: #015349;
#   color: #f1f1f1;
# }
# #T_22dc0_row8_col10 {
#   background-color: #a6dcd4;
#   color: #000000;
# }
# #T_22dc0_row8_col12 {
#   background-color: #7ccabe;
#   color: #000000;
# }
# #T_22dc0_row8_col13, #T_22dc0_row11_col2 {
#   background-color: #c08430;
#   color: #f1f1f1;
# }
# #T_22dc0_row9_col0, #T_22dc0_row12_col9 {
#   background-color: #7fccc0;
#   color: #000000;
# }
# #T_22dc0_row9_col1 {
#   background-colo

# %%
# (Optional) Visualise with a Heat Map which is part of Seaborn library 
import seaborn as sns
correlation = house. corr ()  
sns. heatmap (correlation)
# Out:
# <Axes: >

# %%
# Optional: Explore the distribution and outliers of datasets using boxplot
from scipy import stats

fig, axs = plt.subplots(ncols=7, nrows=2, figsize=(20, 10))
index = 0
axs = axs.flatten()
for k,v in house.items():
    sns.boxplot(y=k, data=house, ax=axs[index])
    index += 1
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %%
# Optional : Additional visualizations. Check the linear relation of each variable with y
from sklearn import preprocessing

# Let's scale the columns before plotting them against MEDV
min_max_scaler = preprocessing.MinMaxScaler()
column_sels = ['lstat', 'indus', 'nox', 'ptratio', 'rm', 'tax', 'dis', 'age']
x = house.loc[:,column_sels]
y = house['medv']
x = pd.DataFrame(data=min_max_scaler.fit_transform(x), columns=column_sels)
fig, axs = plt.subplots(ncols=4, nrows=2, figsize=(20, 10))
index = 0
axs = axs.flatten()
for i, k in enumerate(column_sels):
    sns.regplot(y=y, x=x[k], ax=axs[i])
    plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %%
# Optional: Additional exploration of all variables
fig, axs = plt.subplots(ncols=7, nrows=2, figsize=(20, 10))
index = 0
axs = axs.flatten()
for k,v in house.items():
    sns.histplot(v, ax=axs[index])
    index += 1
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)
